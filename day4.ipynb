# %%
import pandas as pd

# %%
df = pd.read_csv('https://github.com/singhrau0/Big-Data-Preprocessing/raw/refs/heads/main/fifa21_raw_data.csv')
# Out:
# C:\Users\Abhiram\AppData\Local\Temp\ipykernel_17232\665043767.py:1: DtypeWarning: Columns (76) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://github.com/singhrau0/Big-Data-Preprocessing/raw/refs/heads/main/fifa21_raw_data.csv')

# %%
df
# Out:
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# ...

# %%
df.isnull().sum()
# Out:
# photoUrl       0
# LongName       0
# playerUrl      0
# Nationality    0
# Positions      0
#               ..
# PAS            0
# DRI            0
# DEF            0
# PHY            0
# Hits           0
# Length: 77, dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop('Loan Date End', axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# photoUrl       0
# LongName       0
# playerUrl      0
# Nationality    0
# Positions      0
#               ..
# PAS            0
# DRI            0
# DEF            0
# PHY            0
# Hits           0
# Length: 76, dtype: int64

# %%
df[df['LongName'] == 'Lionel Messi']
# Out:
#                                            photoUrl      LongName  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png  Lionel Messi
#
#                                            playerUrl Nationality Positions  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina  RW ST CF
#
#        Name  Age  ↓OVA  POT                        Team & Contract      ID  \
# 0  L. Messi   33    93   93  \n\n\n\nFC Barcelona\n2004 ~ 2021\n\n  158023
#
#   Height  Weight  foot  BOV  BP  Growth       Joined   Value   Wage  \
# 0   5'7"  159lbs  Left   93  RW       0  Jul 1, 2004  €67.5M  €560K
#
#   Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# 0        €138.4M        429        85         95                70
#
#    Short Passing  Volleys  Skill  Dribbling  Curve  FK Accuracy  Long Passing  \
# 0             91       88    470         96     93           94            91
#
#    Ball Control  Movement  Acceleration  Sprint Speed  Agility  Reactions  \
# ...

# %%
df['Positions']
# Out:
# 0        RW ST CF
# 1           ST LW
# 2              GK
# 3          CAM CM
# 4          LW CAM
#            ...
# 18974          CB
# 18975          ST
# 18976          CB
# 18977          CM
# 18978         CDM
# Name: Positions, Length: 18978, dtype: object

# %%
df['newcolumn'] = df['Positions'].str.split(' ').str[-1]

# %%
df[df['newcolumn'].str.contains('RW')]
# Out:
#                                                photoUrl         LongName  \
# 6      https://cdn.sofifa.com/players/231/747/21_60.png    Kylian Mbappé
# 8      https://cdn.sofifa.com/players/209/331/21_60.png    Mohamed Salah
# 22     https://cdn.sofifa.com/players/202/652/21_60.png  Raheem Sterling
# 54     https://cdn.sofifa.com/players/189/596/21_60.png    Thomas Müller
# 74     https://cdn.sofifa.com/players/208/670/21_60.png     Hakim Ziyech
# ...                                                 ...              ...
# 18897  https://cdn.sofifa.com/players/252/809/21_60.png    Ji Yong Jeong
# 18907  https://cdn.sofifa.com/players/257/699/21_60.png   Shayden Morris
# 18909  https://cdn.sofifa.com/players/252/332/21_60.png        Wei Zhang
# 18925  https://cdn.sofifa.com/players/243/725/21_60.png   Darren Collins
# 18965  https://cdn.sofifa.com/players/243/790/21_60.png     Zhen'ao Wang
#
#                                                playerUrl          Nationality  \
# ...

# %%
df['Franchise'] = df['Team & Contract'].str.split('\n').str[4:-2].str[0]

# %%
df
# Out:
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# ...

# %%
df['Year'] = df['Team & Contract'].str.split('\n').str[4:-2].str[1]

# %%
df
# Out:
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# ...

# %%
df['start_year'] = df['Year'].str.split('~').str[0]

# %%
df['end_year'] = df['Year'].str.split('~').str[1]

# %%
df.drop('Team & Contract', axis=1, inplace=True)

# %%
df
# Out:
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# ...

# %%
df['Height']
# Out:
# 0         5'7"
# 1         6'2"
# 2         6'2"
# 3        5'11"
# 4         5'9"
#          ...
# 18974    5'10"
# 18975     5'7"
# 18976    5'10"
# 18977     5'9"
# 18978     5'9"
# Name: Height, Length: 18978, dtype: object

# %%
df['Height'].str.split("'").str[0].astype(int)
# Out:
# 0        5
# 1        6
# 2        6
# 3        5
# 4        5
#         ..
# 18974    5
# 18975    5
# 18976    5
# 18977    5
# 18978    5
# Name: Height, Length: 18978, dtype: int32

# %%
df['Height'].str.split("'").str[0]
# Out:
# 0        5
# 1        6
# 2        6
# 3        5
# 4        5
#         ..
# 18974    5
# 18975    5
# 18976    5
# 18977    5
# 18978    5
# Name: Height, Length: 18978, dtype: object

# %%
df
# Out:
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# ...

# %%
df['Height']
# Out:
# 0         5'7"
# 1         6'2"
# 2         6'2"
# 3        5'11"
# 4         5'9"
#          ...
# 18974    5'10"
# 18975     5'7"
# 18976    5'10"
# 18977     5'9"
# 18978     5'9"
# Name: Height, Length: 18978, dtype: object

# %%
df
# Out:
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# ...

# %%
df['Height'].str.split("'").str[0].astype(int)
# Out:
# 0        5
# 1        6
# 2        6
# 3        5
# 4        5
#         ..
# 18974    5
# 18975    5
# 18976    5
# 18977    5
# 18978    5
# Name: Height, Length: 18978, dtype: int32

# %%
df['Height'].str.split("'").str[1].str.split('"').str[0].astype(int)
# Out:
# 0         7
# 1         2
# 2         2
# 3        11
# 4         9
#          ..
# 18974    10
# 18975     7
# 18976    10
# 18977     9
# 18978     9
# Name: Height, Length: 18978, dtype: int32

# %%
df['Height'] = (df['Height'].str.split("'").str[0].astype(int) * 30.48) + (df['Height'].str.split("'").str[1].str.split('"').str[0].astype(int) * 2.54)

# %%
df['Height']
# Out:
# 0        170.18
# 1        187.96
# 2        187.96
# 3        180.34
# 4        175.26
#           ...
# 18974    177.80
# 18975    170.18
# 18976    177.80
# 18977    175.26
# 18978    175.26
# Name: Height, Length: 18978, dtype: float64

# %%
df['Weight']  = df['Weight'].str.replace('lbs','').astype(int)

# %%
df
# Out:
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# ...

# %%
df['Release Clause']
# Out:
# 0        €138.4M
# 1         €75.9M
# 2        €159.4M
# 3          €161M
# 4        €166.5M
#           ...
# 18974       €57K
# 18975      €165K
# 18976       €70K
# 18977      €165K
# 18978      €167K
# Name: Release Clause, Length: 18978, dtype: object

# %%
df[(~df['Release Clause'].str.contains('K')) & (~df['Release Clause'].str.contains('M'))]
# Out:
#                                                photoUrl  \
# 205    https://cdn.sofifa.com/players/173/731/21_60.png
# 250    https://cdn.sofifa.com/players/200/888/21_60.png
# 257    https://cdn.sofifa.com/players/193/105/21_60.png
# 288    https://cdn.sofifa.com/players/230/347/21_60.png
# 292    https://cdn.sofifa.com/players/230/225/21_60.png
# ...                                                 ...
# 18497  https://cdn.sofifa.com/players/242/601/21_60.png
# 18569  https://cdn.sofifa.com/players/240/392/21_60.png
# 18580  https://cdn.sofifa.com/players/236/818/21_60.png
# 18638  https://cdn.sofifa.com/players/252/516/21_60.png
# 18696  https://cdn.sofifa.com/players/232/888/21_60.png
#
#                                LongName  \
# 205                         Gareth Bale
# 250           Danilo Luís Hélio Pereira
# 257                     Alphonse Areola
# 288      Welington Kauê Dano Nascimento
# 292    Juan Everton Mestres de Mesquita
# ...                                 ...
# ...

# %%
df.to_csv('Data.csv', index=False)

# %%
df['Release Clause'] = df['Release Clause'].str.replace('€','').str.replace('K','000').str.replace('M','000000').astype(float)

# %%
df['Release Clause']
# Out:
# 0              138.4
# 1               75.9
# 2              159.4
# 3        161000000.0
# 4              166.5
#             ...
# 18974        57000.0
# 18975       165000.0
# 18976        70000.0
# 18977       165000.0
# 18978       167000.0
# Name: Release Clause, Length: 18978, dtype: float64

# %%
df[['Franchise','Value']].groupby('Franchise').sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df[['Franchise','Value']].groupby('Franchise').sum()
#
# File c:\Users\Abhiram\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Abhiram\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
# ...
