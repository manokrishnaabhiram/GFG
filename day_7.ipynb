# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np

# %%
df = pd.read_csv('https://github.com/singhrau0/Big-Data-Preprocessing/raw/refs/heads/main/Movie_Data.csv')

# %%
df
# Out:
#      Marketin_expense  Production_expense  Multiplex_coverage     Budget  \
# 0             20.1264               59.62               0.462  36524.125
# 1             20.5462               69.14               0.531  35668.655
# 2             20.5458               69.14               0.531  39912.675
# 3             20.6474               59.36               0.542  38873.890
# 4             21.3810               59.36               0.542  39701.585
# ..                ...                 ...                 ...        ...
# 501           21.2526               78.86               0.427  36624.115
# 502           20.9054               78.86               0.427  33996.600
# 503           21.2152               78.86               0.427  38751.680
# 504           22.1918               78.86               0.427  37740.670
# 505           20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
sns.scatterplot(df,y='Collection', x='Budget')
# Out:
# <Axes: xlabel='Budget', ylabel='Collection'>

# %%
df.keys()
# Out:
# Index(['Marketin_expense', 'Production_expense', 'Multiplex_coverage',
#        'Budget', 'Movie_length', 'Lead_ Actor_Rating', 'Lead_Actress_rating',
#        'Director_rating', 'Producer_rating', 'Critic_rating', 'Trailer_views',
#        'Time_taken', 'Twitter_hastags', 'Avg_age_actors', 'Num_multiplex',
#        '3D_available', 'Genre_Thriller', 'Genre_Drama', 'Genre_Comedy',
#        'Collection'],
#       dtype='object')

# %%
sns.scatterplot(df,y='Collection', x='3D_available')
# Out:
# <Axes: xlabel='3D_available', ylabel='Collection'>

# %%
sns.scatterplot(df,y='Collection', x='Budget')
# Out:
# <Axes: xlabel='Budget', ylabel='Collection'>

# %%
sns.scatterplot(df,y='Collection', x='Lead_ Actor_Rating')
# Out:
# <Axes: xlabel='Lead_ Actor_Rating', ylabel='Collection'>

# %%
df1 = df.corr()
df1.keys()
# Out:
# Index(['Marketin_expense', 'Production_expense', 'Multiplex_coverage',
#        'Budget', 'Movie_length', 'Lead_ Actor_Rating', 'Lead_Actress_rating',
#        'Director_rating', 'Producer_rating', 'Critic_rating', 'Trailer_views',
#        'Time_taken', 'Twitter_hastags', 'Avg_age_actors', 'Num_multiplex',
#        '3D_available', 'Genre_Thriller', 'Genre_Drama', 'Genre_Comedy',
#        'Collection'],
#       dtype='object')

# %%
sns.scatterplot(x='Lead_ Actor_Rating', y='Multiplex_coverage', data=df)
# Out:
# <Axes: xlabel='Lead_ Actor_Rating', ylabel='Multiplex_coverage'>

# %%
sns.scatterplot(x='Lead_Actress_rating',y = 'Lead_ Actor_Rating', data=df)
# Out:
# <Axes: xlabel='Lead_Actress_rating', ylabel='Lead_ Actor_Rating'>

# %%
sns.heatmap(df1)
# Out:
# <Axes: >

# %%
sns.lineplot(x='Lead_ Actor_Rating', y='Multiplex_coverage', data=df)
# Out:
# <Axes: xlabel='Lead_ Actor_Rating', ylabel='Multiplex_coverage'>

# %%
fig,axis = plt.subplots(2,2, figsize=(10,10))
sns.boxplot(x='Lead_ Actor_Rating', data=df, ax=axis[0][0])
sns.scatterplot(x='Lead_Actress_rating', y='Lead_ Actor_Rating', data=df, ax=axis[0][1])
sns.heatmap(df1, ax=axis[1][0])
sns.lineplot(x='Lead_ Actor_Rating', y='Multiplex_coverage', data=df, ax=axis[1][1])
# Out:
# <Axes: xlabel='Lead_ Actor_Rating', ylabel='Multiplex_coverage'>

# %%
df['Genre_Comedy'].value_counts()
# Out:
# Genre_Comedy
# 0    351
# 1    155
# Name: count, dtype: int64

# %%
df.loc[df['Genre_Thriller'] == 1,'Genre_Thriller'] = 'triller'
df.loc[df['Genre_Drama'] == 1,'Genre_Thriller'] = 'Drama'
df.loc[df['Genre_Comedy'] == 1,'Genre_Thriller'] = 'Comedy'
df.loc[df['Genre_Thriller'] == 0,'Genre_Thriller'] = 'Unknown'

# %%
df
# Out:
#      Marketin_expense  Production_expense  Multiplex_coverage     Budget  \
# 0             20.1264               59.62               0.462  36524.125
# 1             20.5462               69.14               0.531  35668.655
# 2             20.5458               69.14               0.531  39912.675
# 3             20.6474               59.36               0.542  38873.890
# 4             21.3810               59.36               0.542  39701.585
# ..                ...                 ...                 ...        ...
# 501           21.2526               78.86               0.427  36624.115
# 502           20.9054               78.86               0.427  33996.600
# 503           21.2152               78.86               0.427  38751.680
# 504           22.1918               78.86               0.427  37740.670
# 505           20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
df.rename(columns={'Genre_Thriller': 'Genre'},inplace=True)

# %%
df
# Out:
#      Marketin_expense  Production_expense  Multiplex_coverage     Budget  \
# 0             20.1264               59.62               0.462  36524.125
# 1             20.5462               69.14               0.531  35668.655
# 2             20.5458               69.14               0.531  39912.675
# 3             20.6474               59.36               0.542  38873.890
# 4             21.3810               59.36               0.542  39701.585
# ..                ...                 ...                 ...        ...
# 501           21.2526               78.86               0.427  36624.115
# 502           20.9054               78.86               0.427  33996.600
# 503           21.2152               78.86               0.427  38751.680
# 504           22.1918               78.86               0.427  37740.670
# 505           20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
gt = df[['Genre', 'Collection']].groupby('Genre').count()

# %%
fig,axis  = plt.subplots(2,2,figsize=(10, 6))
axis[0,1].pie(gt['Collection'], labels=gt.index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x23c7a923450>,
# ...
#  [Text(0.6287565890065481, 0.9025880299343942, 'Comedy'),
#   Text(-0.898666945576851, 0.6343482646997415, 'Drama'),
#   Text(-1.000595146272514, -0.45695662075943977, 'Unknown'),
#   Text(0.46316018650273066, -0.9977387642257647, 'triller')],
#  [Text(0.3429581394581171, 0.49232074360057865, '30.6%'),
#   Text(-0.49018197031464594, 0.3460081443816771, '19.2%'),
#   Text(-0.5457791706940984, -0.2492490658687853, '14.0%'),
#   Text(0.2526328290014894, -0.5442211441231443, '36.2%')])

# %%
df.keys()
# Out:
# Index(['Marketin_expense', 'Production_expense', 'Multiplex_coverage',
#        'Budget', 'Movie_length', 'Lead_ Actor_Rating', 'Lead_Actress_rating',
#        'Director_rating', 'Producer_rating', 'Critic_rating', 'Trailer_views',
#        'Time_taken', 'Twitter_hastags', 'Avg_age_actors', 'Num_multiplex',
#        '3D_available', 'Genre', 'Genre_Drama', 'Genre_Comedy', 'Collection'],
#       dtype='object')

# %%
(df['Collection'] *1000000) - (df['Budget'])
# Out:
# 0      2266666.667
# 1      2106666.667
# 2      2980000.000
# 3      2893333.333
# 4      3080000.000
#           ...
# 501    2160000.000
# 502    2040000.000
# 503    2260000.000
# 504    2133333.333
# 505    1933333.333
# Name: Collection, Length: 506, dtype: float64
